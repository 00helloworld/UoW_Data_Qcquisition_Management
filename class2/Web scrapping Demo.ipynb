# %%
# Understanding tags in html: https://web.stanford.edu/group/csp/cs21/htmlcheatsheet.pdf

# %%
from bs4 import BeautifulSoup # Good for webscrapping for pulling HTML and XML files
import requests # to download webpage

# %%
url = "https://www.uwinnipeg.ca/"

# %%
# We use get to download the content of the web page in txt format and store in a variable called data:

data = requests.get(url).text

# %%
# We create BeautifulSoup object using the BeautifulSoup Constructor

soup = BeautifulSoup(data, 'html5lib') # create a soup using variable data

# %%
# Scrap all links

for link in soup.find_all('a', href =True): # in html, anchor/link is representated by the tag <a>
    print(link.get('href'))
# Out:
# https://www.uwinnipeg.ca/covid-19/index.html
# #
# #main
# /
# #
# https://www.uwinnipeg.ca/future-student/academic-programs.html
# https://www.uwinnipeg.ca/future-student/academic-programs.html
# https://www.uwinnipeg.ca/future-student/index.html
# https://www.uwinnipeg.ca/graduate-studies/index.html
# https://www.uwinnipeg.ca/future-student/intl-students.html
# https://collegiate.uwinnipeg.ca
# https://pace.uwinnipegcourses.ca
# https://www.uwinnipeg.ca/elp/index.html
# https://www.uwinnipeg.ca/awards/index.html
# https://www.uwinnipeg.ca/factsheets/index.html
# https://www.uwinnipeg.ca/campus-living/index.html
# https://www.uwinnipeg.ca/future-student/campus-tours.html
# https://www.uwinnipeg.ca/academics/index.html
# https://www.uwinnipeg.ca/academics/index.html
# https://www.uwinnipeg.ca/academics/faculties.html
# https://www.uwinnipeg.ca/academics/programs/index.html
# https://www.uwinnipeg.ca/academics/centres-and-chairs.html
# https://www.uwinnipeg.ca/academics/colleges.html
# https://www.uwinnipeg.ca/academics/calendar/index.html
# https://library.uwinnipeg.ca
# https://nexus.uwinnipeg.ca/
# https://www.uwinnipeg.ca/registration/index.html
# https://webadv.uwinnipeg.ca/WebAdvisor/WebAdvisor
# https://www.uwinnipeg.ca/campus-life/index.html
# https://www.uwinnipeg.ca/campus-life/index.html
# https://www.uwinnipeg.ca/arts-and-culture/index.html
# https://www.bkstr.com/winnipegstore/home
# https://recreationservices.uwinnipeg.ca/
# https://www.uwinnipeg.ca/campus-living/index.html
# https://www.uwinnipeg.ca/campus-restaurants/index.html
# https://www.wesmen.ca/
# https://www.uwinnipeg.ca/student-wellness/index.html
# https://www.uwinnipeg.ca/art-gallery/index.html
# https://www.uwinnipeg.ca/events-calendar/index.html
# http://uniter.ca/
# https://theuwsa.ca/
# https://www.uwinnipeg.ca/about/index.html
# https://www.uwinnipeg.ca/about/index.html
# https://www.uwinnipeg.ca/president/index.html
# https://www.uwinnipeg.ca/about/administration/index.html
# https://www.uwinnipeg.ca/about/campus-services/index.html
# https://www.uwinnipeg.ca/event-services/index.html
# https://www.uwinnipeg.ca/hr/employment.html
# https://www.uwinnipeg.ca/indigenous/index.html
# https://www.uwinnipeg.ca/publications/index.html
# https://www.uwinnipeg.ca/research/index.html
# https://www.uwinnipeg.ca/maps/index.html
# https://www.uwinnipeg.ca/directory/index.php
# https://www.uwinnipeg.ca/foundation/index.html
# http://uwcrc.ca/
# https://www.uwinnipeg.ca/visitor/index.html
# https://news.uwinnipeg.ca/
# https://www.uwinnipeg.ca/student/index.html
# https://www.uwinnipeg.ca/faculty-staff/index.html
# https://www.uwinnipeg.ca/alumni/index.html
# https://www.uwinnipeg.ca/community/index.html
# https://www.uwinnipeg.ca/future-student/apply/ready-to-apply.html
# https://www.uwinnipeg.ca/visitor/index.html
# https://www.uwinnipeg.ca/foundation/index.html
# https://www.uwinnipeg.ca/privacy/web-privacy-notice.html
# https://www.uwinnipeg.ca/branding/index.html
# https://www.instagram.com/uwinnipeg/
# https://www.facebook.com/uwinnipeg
# https://twitter.com/uwinnipeg
# https://www.youtube.com/user/uwinnipeg
# https://www.linkedin.com/school/university-of-winnipeg/
# https://secure.flickr.com/photos/uwinnipeg
# https://netcommunity.uwinnipeg.ca/give-programs
# https://www.uwinnipeg.ca/indigenous/land-acknowledgement.html
# #
# #
# #

# %%
# Scrap all the images Tag
for link in soup.find_all('img'): #in html, image is representaed by the tag <img>
    print(link)
    print(link.get('src'))
# Out:
# <img alt="The University of Winnipeg" id="logo-header" src="_files/images/redesign-2020/uwinnipeg-logo-black-4x.png"/>
# _files/images/redesign-2020/uwinnipeg-logo-black-4x.png
# <img alt="Student and professor in math classrom" src="_files/video/teaching-banner.jpg"/>
# _files/video/teaching-banner.jpg
# <img alt="Students talking on a bench" src="_files/video/student-experience-banner.jpg"/>
# _files/video/student-experience-banner.jpg
# <img alt="Student in marsh" src="_files/video/research-banner.jpg"/>
# _files/video/research-banner.jpg
# <img alt="Elder talking with students" src="_files/video/diversity-banner.jpg"/>
# _files/video/diversity-banner.jpg
# <img alt="Three Students" src="_files/images/homepage-2021/three-students.jpg"/>
# _files/images/homepage-2021/three-students.jpg
# <img alt="Winter Term to start on January 10" class="attachment-uofw-medium size-uofw-medium wp-post-image" height="518" loading="lazy" sizes="(max-width: 920px) 100vw, 920px" src="https://news.uwinnipeg.ca/wp-content/uploads/2021/07/Back2gether.jpg" srcset="https://news.uwinnipeg.ca/wp-content/uploads/2021/07/Back2gether.jpg 2320w, https://news.uwinnipeg.ca/wp-content/uploads/2021/07/Back2gether-1536x863.jpg 1536w, https://news.uwinnipeg.ca/wp-content/uploads/2021/07/Back2gether-2048x1151.jpg 2048w, https://news.uwinnipeg.ca/wp-content/uploads/2021/07/Back2gether-1160x652.jpg 1160w, https://news.uwinnipeg.ca/wp-content/uploads/2021/07/Back2gether-920x518.jpg 920w, https://news.uwinnipeg.ca/wp-content/uploads/2021/07/Back2gether-580x326.jpg 580w, https://news.uwinnipeg.ca/wp-content/uploads/2021/07/Back2gether-440x248.jpg 440w, https://news.uwinnipeg.ca/wp-content/uploads/2021/07/Back2gether-320x180.jpg 320w" width="920"/>
# https://news.uwinnipeg.ca/wp-content/uploads/2021/07/Back2gether.jpg
# <img alt="Schroeder Foundation gift supports three UWinnipeg students" class="attachment-uofw-medium size-uofw-medium wp-post-image" height="518" loading="lazy" sizes="(max-width: 920px) 100vw, 920px" src="https://news.uwinnipeg.ca/wp-content/uploads/2021/12/Wesley-Hall.jpg" srcset="https://news.uwinnipeg.ca/wp-content/uploads/2021/12/Wesley-Hall.jpg 2320w, https://news.uwinnipeg.ca/wp-content/uploads/2021/12/Wesley-Hall-1536x863.jpg 1536w, https://news.uwinnipeg.ca/wp-content/uploads/2021/12/Wesley-Hall-2048x1151.jpg 2048w, https://news.uwinnipeg.ca/wp-content/uploads/2021/12/Wesley-Hall-1160x652.jpg 1160w, https://news.uwinnipeg.ca/wp-content/uploads/2021/12/Wesley-Hall-920x518.jpg 920w, https://news.uwinnipeg.ca/wp-content/uploads/2021/12/Wesley-Hall-580x326.jpg 580w, https://news.uwinnipeg.ca/wp-content/uploads/2021/12/Wesley-Hall-440x248.jpg 440w, https://news.uwinnipeg.ca/wp-content/uploads/2021/12/Wesley-Hall-320x180.jpg 320w" width="920"/>
# https://news.uwinnipeg.ca/wp-content/uploads/2021/12/Wesley-Hall.jpg
# <img alt="Looking back on 2021 in the news" class="attachment-uofw-medium size-uofw-medium wp-post-image" height="518" loading="lazy" sizes="(max-width: 920px) 100vw, 920px" src="https://news.uwinnipeg.ca/wp-content/uploads/2021/12/2021inthenews-1.jpg" srcset="" width="920"/>
# https://news.uwinnipeg.ca/wp-content/uploads/2021/12/2021inthenews-1.jpg
# <img alt="Carriera Lamoureux" class="attachment-uofw-medium size-uofw-medium wp-post-image" height="518" loading="lazy" sizes="(max-width: 920px) 100vw, 920px" src="https://news.uwinnipeg.ca/wp-content/uploads/2021/11/carriera-lamoureux-1160x652-1.jpg" srcset="https://news.uwinnipeg.ca/wp-content/uploads/2021/11/carriera-lamoureux-1160x652-1.jpg 1160w, https://news.uwinnipeg.ca/wp-content/uploads/2021/11/carriera-lamoureux-1160x652-1-920x518.jpg 920w, https://news.uwinnipeg.ca/wp-content/uploads/2021/11/carriera-lamoureux-1160x652-1-580x326.jpg 580w, https://news.uwinnipeg.ca/wp-content/uploads/2021/11/carriera-lamoureux-1160x652-1-440x248.jpg 440w, https://news.uwinnipeg.ca/wp-content/uploads/2021/11/carriera-lamoureux-1160x652-1-320x180.jpg 320w" width="920"/>
# https://news.uwinnipeg.ca/wp-content/uploads/2021/11/carriera-lamoureux-1160x652-1.jpg
# <img alt="Happy Holiday Season" class="attachment-uofw-medium size-uofw-medium wp-post-image" height="518" loading="lazy" sizes="(max-width: 920px) 100vw, 920px" src="https://news.uwinnipeg.ca/wp-content/uploads/2018/12/holiday-2018-300x200.jpg" srcset="https://news.uwinnipeg.ca/wp-content/uploads/2018/12/holiday-2018-300x200.jpg 300w, https://news.uwinnipeg.ca/wp-content/uploads/2018/12/holiday-2018-363x242.jpg 363w, https://news.uwinnipeg.ca/wp-content/uploads/2018/12/holiday-2018.jpg 735w" width="920"/>
# https://news.uwinnipeg.ca/wp-content/uploads/2018/12/holiday-2018-300x200.jpg
# <img alt="" aria-hidden="true" id="footer-logo" src="_files/images/redesign-2020/uwinnipeg-white-4x.png"/>
# _files/images/redesign-2020/uwinnipeg-white-4x.png
# <img alt="Instagram" src="_files/images/redesign-2020/instagram.svg"/>
# _files/images/redesign-2020/instagram.svg
# <img alt="Facebook" src="_files/images/redesign-2020/facebook.svg"/>
# _files/images/redesign-2020/facebook.svg
# <img alt="Twitter" src="_files/images/redesign-2020/twitter.svg"/>
# _files/images/redesign-2020/twitter.svg
# <img alt="YouTube" src="_files/images/redesign-2020/youtube.svg"/>
# _files/images/redesign-2020/youtube.svg
# <img alt="LinkedIn" src="_files/images/redesign-2020/linkedin.svg"/>
# _files/images/redesign-2020/linkedin.svg
# <img alt="Flickr" src="_files/images/redesign-2020/flickr.svg"/>
# _files/images/redesign-2020/flickr.svg

# %% [markdown]
# ## Scrap data from a Table in HTML

# %%
from bs4 import BeautifulSoup # Good for webscrapping for pulling HTML and XML files
import requests # to download webpage

# %%
# The url below conatins an html table with data about colors and colour codes
url = "https://elasticbeanstalk-us-east-2-340729127361.s3.us-east-2.amazonaws.com/colour_codes.html"

# %% [markdown]
#  Before proceeding to scrape a website, you need to first examine the content and the way it is organised on the website.  The check the link abouve on the browser

# %%
# get the content of the webpage in the text format in a variable called data
data = requests.get(url).text

# %%
soup = BeautifulSoup(data, "html5lib")

# %%
# Find a html table in the web page

table = soup.find('table') # in html table is represented by the tag <table>

# %%
# Get all the rows from the table

for row in table.find_all('tr'): # in the html table row is represented by tag <tr>
    #Get all columns in each row
    cols = row.find_all('td') #in html, a column is represented by the tagg <td>
    color_name = cols[2].string # store the value in column 3 as color_name
    color_code = cols[3].string # store the value in column 4 as color_code
    print("colour name is {}   Colour code is {}".format(color_name, color_code))
# Out:
# colour name is Color Name   Colour code is None
# colour name is lightsalmon   Colour code is #FFA07A
# colour name is salmon   Colour code is #FA8072
# colour name is darksalmon   Colour code is #E9967A
# colour name is lightcoral   Colour code is #F08080
# colour name is coral   Colour code is #FF7F50
# colour name is tomato   Colour code is #FF6347
# colour name is orangered   Colour code is #FF4500
# colour name is gold   Colour code is #FFD700
# colour name is orange   Colour code is #FFA500
# colour name is darkorange   Colour code is #FF8C00
# colour name is lightyellow   Colour code is #FFFFE0
# colour name is lemonchiffon   Colour code is #FFFACD
# colour name is papayawhip   Colour code is #FFEFD5
# colour name is moccasin   Colour code is #FFE4B5
# colour name is peachpuff   Colour code is #FFDAB9
# colour name is palegoldenrod   Colour code is #EEE8AA
# colour name is khaki   Colour code is #F0E68C
# colour name is darkkhaki   Colour code is #BDB76B
# colour name is yellow   Colour code is #FFFF00
# colour name is lawngreen   Colour code is #7CFC00
# colour name is chartreuse   Colour code is #7FFF00
# colour name is limegreen   Colour code is #32CD32
# colour name is lime   Colour code is #00FF00
# colour name is forestgreen   Colour code is #228B22
# colour name is green   Colour code is #008000
# colour name is powderblue   Colour code is #B0E0E6
# colour name is lightblue   Colour code is #ADD8E6
# colour name is lightskyblue   Colour code is #87CEFA
# colour name is skyblue   Colour code is #87CEEB
# colour name is deepskyblue   Colour code is #00BFFF
# colour name is lightsteelblue   Colour code is #B0C4DE
# colour name is dodgerblue   Colour code is #1E90FF
